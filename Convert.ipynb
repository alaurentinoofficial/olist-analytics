# %%
import pandas as pd

# %% [markdown]
# ## Payments

# %%
df = pd.read_csv('./csv/olist_order_payments_dataset.csv')
df.to_csv('./csv/olist_order_payments_dataset.csv')

# %%
df.to_csv('./csv/olist_order_payments_dataset.csv', index=False)

# %% [markdown]
# ## Custommers

# %%
df = pd.read_csv('./csv/olist_customers_dataset.csv')

# %%
df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df.to_csv('./csv/olist_customers_dataset.csv', index=False)

# %% [markdown]
# ## Estados

# %%
df = pd.read_csv('./csv/states_map.csv')
df.to_csv('./csv/states_map.csv', index=False)

# %% [markdown]
# ## Carrinho de Compras

# %%
df = pd.read_csv('./csv/olist_order_items_dataset.csv')
df.to_csv('./csv/olist_order_items_dataset.csv', index=False)

# %% [markdown]
# ## Vendedores

# %%
df = pd.read_csv('./csv/olist_sellers_dataset.csv')

# %%
df
# Out:
#       Unnamed: 0                         seller_id  seller_zip_code_prefix  \
# 0              0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1              1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2              2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3              3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4              4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# 5              5  c240c4061717ac1806ae6ee72be3533b                   20920
# 6              6  e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 7              7  1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 8              8  768a86e36ad6aae3d03ee3c6433d61df                    1529
# 9              9  ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
# 10            10  8cb7c5ddf41f4d506eba76e9a4702a25                   75110
# ...

# %%
df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df.to_csv('./csv/olist_sellers_dataset.csv', index=False)
